# %% [markdown]
# DATA WRANGING II
#
# Create an "Academic performance" dataset of students and perform the
# following operations using Python.
# 1. Scan all variables for missing values and inconsistencies. If there are missing values and/or inconsistencies, use any of the suitable techniques to deal with them.
# 2. Scan all numeric variables for outliers. If there are outliers, use any of the suitable techniques to deal with them.
# 3. Apply data transformations on at least one of the variables. The purpose of this transformation should be one of the following reasons: to change the scale for better understanding of the variable, to convert a non-linear relation into a linear one, or to decrease the skewness and convert the distribution into a normal distribution.
# Reason and document your approach properly.

# %% [markdown]
# Importing the libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Loading dataset into dataframe

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#     gender NationalITy  ... StudentAbsenceDays Class
# 0        M          KW  ...            Under-7     M
# 1        M          KW  ...            Under-7     M
# 2        M          KW  ...            Above-7     L
# 3        M          KW  ...            Above-7     L
# 4        M          KW  ...            Above-7     M
# ..     ...         ...  ...                ...   ...
# 475      F      Jordan  ...            Above-7     L
# 476      F      Jordan  ...            Under-7     M
# 477      F      Jordan  ...            Under-7     M
# 478      F      Jordan  ...            Above-7     L
# 479      F      Jordan  ...            Above-7     L
#
# [480 rows x 17 columns]

# %% [markdown]
# Summarizing variables using their dtypes

# %%
df.dtypes
# Out:
# gender                       object
# NationalITy                  object
# PlaceofBirth                 object
# StageID                      object
# GradeID                      object
# SectionID                    object
# Topic                        object
# Semester                     object
# Relation                     object
# raisedhands                 float64
# VisITedResources            float64
# AnnouncementsView           float64
# Discussion                    int64
# ParentAnsweringSurvey        object
# ParentschoolSatisfaction     object
# StudentAbsenceDays           object
# Class                        object
# dtype: object

# %% [markdown]
# Scan for missing values

# %%
df.isna().sum()
# Out:
# gender                       0
# NationalITy                  0
# PlaceofBirth                 0
# StageID                      0
# GradeID                      0
# SectionID                    0
# Topic                       10
# Semester                     0
# Relation                    15
# raisedhands                 20
# VisITedResources             4
# AnnouncementsView           11
# Discussion                   0
# ParentAnsweringSurvey        0
# ParentschoolSatisfaction     5
# StudentAbsenceDays           5
# Class                       13
# dtype: int64

# %% [markdown]
# missing value percent

# %%
100*df.isna().sum()/len(df)
# Out:
# gender                      0.000000
# NationalITy                 0.000000
# PlaceofBirth                0.000000
# StageID                     0.000000
# GradeID                     0.000000
# SectionID                   0.000000
# Topic                       2.083333
# Semester                    0.000000
# Relation                    3.125000
# raisedhands                 4.166667
# VisITedResources            0.833333
# AnnouncementsView           2.291667
# Discussion                  0.000000
# ParentAnsweringSurvey       0.000000
# ParentschoolSatisfaction    1.041667
# StudentAbsenceDays          1.041667
# Class                       2.708333
# dtype: float64

# %% [markdown]
# replacing missing values with 0(Arbitrary value) for VisITedResources

# %%
df["VisITedResources"].fillna(0, inplace = True)
df["VisITedResources"].isna().sum()
# Out:
# 0

# %%
df
# Out:
#     gender NationalITy  ... StudentAbsenceDays Class
# 0        M          KW  ...            Under-7     M
# 1        M          KW  ...            Under-7     M
# 2        M          KW  ...            Above-7     L
# 3        M          KW  ...            Above-7     L
# 4        M          KW  ...            Above-7     M
# ..     ...         ...  ...                ...   ...
# 475      F      Jordan  ...            Above-7     L
# 476      F      Jordan  ...            Under-7     M
# 477      F      Jordan  ...            Under-7     M
# 478      F      Jordan  ...            Above-7     L
# 479      F      Jordan  ...            Above-7     L
#
# [480 rows x 17 columns]

# %% [markdown]
# Imputing missing values with mean for raisedhands

# %%
z = df["raisedhands"].mean()
df["raisedhands"].fillna(z, inplace = True)
df
# Out:
#     gender NationalITy  ... StudentAbsenceDays Class
# 0        M          KW  ...            Under-7     M
# 1        M          KW  ...            Under-7     M
# 2        M          KW  ...            Above-7     L
# 3        M          KW  ...            Above-7     L
# 4        M          KW  ...            Above-7     M
# ..     ...         ...  ...                ...   ...
# 475      F      Jordan  ...            Above-7     L
# 476      F      Jordan  ...            Under-7     M
# 477      F      Jordan  ...            Under-7     M
# 478      F      Jordan  ...            Above-7     L
# 479      F      Jordan  ...            Above-7     L
#
# [480 rows x 17 columns]

# %%
z = df["AnnouncementsView"].mean()
df["AnnouncementsView"].fillna(z, inplace = True)
df
# Out:
#     gender NationalITy  ... StudentAbsenceDays Class
# 0        M          KW  ...            Under-7     M
# 1        M          KW  ...            Under-7     M
# 2        M          KW  ...            Above-7     L
# 3        M          KW  ...            Above-7     L
# 4        M          KW  ...            Above-7     M
# ..     ...         ...  ...                ...   ...
# 475      F      Jordan  ...            Above-7     L
# 476      F      Jordan  ...            Under-7     M
# 477      F      Jordan  ...            Under-7     M
# 478      F      Jordan  ...            Above-7     L
# 479      F      Jordan  ...            Above-7     L
#
# [480 rows x 17 columns]

# %% [markdown]
# Imputing missing values for a categorical value

# %%
from sklearn.impute import SimpleImputer

# %%
df["Relation"].mode()
# Out:
# 0    Father
# dtype: object

# %%
z = df["Relation"].mode()
df["Relation"].fillna(z[0], inplace = True)
df["Relation"].isna().sum()
# Out:
# 0

# %%
df["Topic"].mode()
# Out:
# 0    IT
# dtype: object

# %%
z = df["Topic"].mode()
df["Topic"].fillna(z[0], inplace = True)
df["Topic"].isna().sum()
# Out:
# 0

# %%
df["Class"].mode()
# Out:
# 0    M
# dtype: object

# %%
z = df["Class"].mode()
df["Class"].fillna(z[0], inplace = True)
df["Class"].isna().sum()
# Out:
# 0

# %%
z = df["ParentschoolSatisfaction"].mode()
df["ParentschoolSatisfaction"].fillna(z[0], inplace = True)
df["ParentschoolSatisfaction"].isna().sum()
# Out:
# 0

# %%
z = df["StudentAbsenceDays"].mode()
df["StudentAbsenceDays"].fillna(z[0], inplace = True)
df["StudentAbsenceDays"].isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                0
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       0
# Semester                    0
# Relation                    0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %% [markdown]
# Scan for outliers

# %%
import seaborn as sb
sb.boxplot(data= df["Discussion"],x= df["Discussion"])

# %% [markdown]
# Creating a DF for outliers detection

# %%
df1 = df.copy(deep = True)
df1
# Out:
#     gender NationalITy  ... StudentAbsenceDays Class
# 0        M          KW  ...            Under-7     M
# 1        M          KW  ...            Under-7     M
# 2        M          KW  ...            Above-7     L
# 3        M          KW  ...            Above-7     L
# 4        M          KW  ...            Above-7     M
# ..     ...         ...  ...                ...   ...
# 475      F      Jordan  ...            Above-7     L
# 476      F      Jordan  ...            Under-7     M
# 477      F      Jordan  ...            Under-7     M
# 478      F      Jordan  ...            Above-7     L
# 479      F      Jordan  ...            Above-7     L
#
# [480 rows x 17 columns]

# %%
df1["Discussion"][4] = 400
df1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     gender NationalITy  ... StudentAbsenceDays Class
# 0        M          KW  ...            Under-7     M
# 1        M          KW  ...            Under-7     M
# 2        M          KW  ...            Above-7     L
# 3        M          KW  ...            Above-7     L
# 4        M          KW  ...            Above-7     M
# ..     ...         ...  ...                ...   ...
# 475      F      Jordan  ...            Above-7     L
# 476      F      Jordan  ...            Under-7     M
# 477      F      Jordan  ...            Under-7     M
# 478      F      Jordan  ...            Above-7     L
# ...

# %% [markdown]
# Locating the outlier

# %%
sb.boxplot(data=df1["Discussion"],x=df1["Discussion"])

# %% [markdown]
# Removing the outliers

# %%
df1[df1["Discussion"] > 100]
# Out:
# Empty DataFrame
# Columns: [gender, NationalITy, PlaceofBirth, StageID, GradeID, SectionID, Topic, Semester, Relation, raisedhands, VisITedResources, AnnouncementsView, Discussion, ParentAnsweringSurvey, ParentschoolSatisfaction, StudentAbsenceDays, Class]
# Index: []

# %%
df1[df1["Discussion"] > 100] = df1["Discussion"].mean()
df1
# Out:
#       gender NationalITy  ... StudentAbsenceDays    Class
# 0          M          KW  ...            Under-7        M
# 1          M          KW  ...            Under-7        M
# 2          M          KW  ...            Above-7        L
# 3          M          KW  ...            Above-7        L
# 4    44.0125     44.0125  ...            44.0125  44.0125
# ..       ...         ...  ...                ...      ...
# 475        F      Jordan  ...            Above-7        L
# 476        F      Jordan  ...            Under-7        M
# 477        F      Jordan  ...            Under-7        M
# 478        F      Jordan  ...            Above-7        L
# 479        F      Jordan  ...            Above-7        L
#
# [480 rows x 17 columns]

# %% [markdown]
# Data Transformation

# %%
df.select_dtypes(exclude=[np.number])
# Out:
#     gender NationalITy  ... StudentAbsenceDays Class
# 0        M          KW  ...            Under-7     M
# 1        M          KW  ...            Under-7     M
# 2        M          KW  ...            Above-7     L
# 3        M          KW  ...            Above-7     L
# 4        M          KW  ...            Above-7     M
# ..     ...         ...  ...                ...   ...
# 475      F      Jordan  ...            Above-7     L
# 476      F      Jordan  ...            Under-7     M
# 477      F      Jordan  ...            Under-7     M
# 478      F      Jordan  ...            Above-7     L
# 479      F      Jordan  ...            Above-7     L
#
# [480 rows x 13 columns]

# %%
df["Semester"].unique()
# Out:
# array(['F', 'S'], dtype=object)

# %%
df["Semester"].value_counts()
# Out:
# F    245
# S    235
# Name: Semester, dtype: int64

# %% [markdown]
# Replacing the categorical value with a number

# %%
df["Semester"].replace({"F":1, "S":0}, inplace = True)
df
# Out:
#     gender NationalITy  ... StudentAbsenceDays Class
# 0        M          KW  ...            Under-7     M
# 1        M          KW  ...            Under-7     M
# 2        M          KW  ...            Above-7     L
# 3        M          KW  ...            Above-7     L
# 4        M          KW  ...            Above-7     M
# ..     ...         ...  ...                ...   ...
# 475      F      Jordan  ...            Above-7     L
# 476      F      Jordan  ...            Under-7     M
# 477      F      Jordan  ...            Under-7     M
# 478      F      Jordan  ...            Above-7     L
# 479      F      Jordan  ...            Above-7     L
#
# [480 rows x 17 columns]
